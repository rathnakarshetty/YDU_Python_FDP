# %% [markdown]
# <a href="https://colab.research.google.com/github/thegeeksam/PythonProgrammingFDP_June2023/blob/main/Day_3_1_Condition_Statement_(16_06_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="lime"> Comparison (or) Relational Operators:
#
# ## <font color="yellow"> Used to compare 2 values.
#
# ![Capture 1.PNG](data:image/png;base64,...)

# %% [markdown]
# ##<font color="Red">Will return **True** or **False** as result
#
# <font color="yellow">The **equal to comparison operator** is two equal signs **<font color="aqua">(==)</font>**,  not a single equal sign **<font color="aqua">(=)**.

# %%
### ---> Guess the Result <--- ###
a = 11
#Returns "True" if the left operand is less than the right operand.
print(a < 10)
# Out:
# False

# %%
### ---> Guess the Result <--- ###
a = 7
# returns "True" if the left operand is less than or equal to the right operand.
print(a <= 5)
# Out:
# False

# %%
### ---> Guess the Result <--- ###
a = 7
#Returns "True" if the left operand is greater than the right operand.
print(a > 5)
# Out:
# True

# %%
### ---> Guess the Result <--- ###
#returns "True" if the left operand is greater than or equal to the right operand.
print(a >= 5)
# Out:
# True

# %%
### ---> Guess the Result <--- ###
#Returns "True" if both the operands are equal
print (a == 7)
# Out:
# True

# %%
### ---> Guess the Result <--- ###
#returns "True" if both the operands are not equal.
print (a != 7)
# Out:
# False

# %% [markdown]
# # <font color="Yellow"> **Conditional Statement** </font>
#
# ##<font color="lime">**One-way if Statements:**</font> A one-way if statement executes the statements if the condition is true.
# ![Capture.PNG](data:image/png;base64,...)

# %%
iA = int(input("Enter an integer: "))
if iA % 5 == 0:
    print("Apple")
else:
    print("Orange")

print("Hello Friends!!!")
# Out:
# Enter an integer:  10
# Apple
# Hello Friends!!!

# %% [markdown]
# ## <font color="lime"> Two-Way if-else Statements: </font>
# A two-way if-else statement decides which statements to execute based on whether
# the condition is true or false.
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
iA = int(input("Enter an integer: "))
if iA % 2 == 0:
    print(iA, "is an even number.")
else:
    print(iA, "is an odd number.")

# %% [markdown]
# ## <font color="lime"> Nested if and Multi-Way if-elif-else Statements:</font>
#
# One <font color="aqua">*if*</font> statement can be placed inside another <font color="aqua">*if*</font> statement to form a nested <font color="aqua">*if* </font>statement.
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
fA = float(input("Enter score: "))
if fA > 100.0:
    grade = "Invalid"
elif fA >= 90.0:
    grade = 'A'
elif fA >= 80.0:
    grade = 'B'
elif fA >= 70.0:
    grade = 'C'
elif fA >= 60.0:
    grade = 'D'
else:
    grade = 'F'

print("Your Grade is:",grade)

# %%
#Find the bug in code
i = 10
if i > 0:
x = 0
y = 1
else:
x = 1
y = 0

print(x,"\n",y)

# %%
#Find the bug in code
i = 10
if i > 0:
    x = 0
     y = 1
else:
    x = 1
    y = 0

print(x,y)

# %%
#------>>> Guess the Output <<<-----
#       .:'
#      __ :'__
#   .'`__`-'__``.
#  :__________.-'
#  :_________:
#   :_________`-;
#    `.__.-.__.'
i = 10
if i > 0:
    x = 0
    y = 1
else:
    x = 1
y = -1

print(x,"\n",y)

# %%
#>>------> Guess the Output <------<<

i = 10
if i > 0:
    x = 0
    y = 1
else:
    x = 1
    y = 0

print(x,y)

# %%
#>>------> Guess the Output <------<<

n = "Lemon"

if ( n == "Apple") :
    print (n)

elif (n =="Orange"):
    print (n)

else:
    print (n)
# Out:
# Lemon

# %%
a = int (input("Enter 1st Number: "))
b = int (input("Enter 2nd Number: "))
c = int (input("Enter 3rd Number: "))
# a = 4 , b = 5, c = 3
#a, b, c = map(int,input("Enter three numbers:").split(" "))
if (a > b):
    if (a > c) :
        print(a, "is the biggest Number.")
    else:
        print(c, "is the biggest Number.")
elif (b > c):
    print(b, "is the biggest Number.")
else:
    print(c, "is the biggest Number.")

# %% [markdown]
# # <font color="Yellow"> Logical (or) Boolean  Operators:
# The logical operators <font color="aqua">not</font>, <font color="aqua">and</font>, and <font color="aqua">or</font> can be used to create a **composite condition**.
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
## >>> Operator "not" <<< ##
age = 24
#print(age > 18)
#print(not (age > 18))

#print(age < 18)
print(not(age < 18))

# %%
 ## >>> Operator "and" <<< ##
age = 24
gender = 'F'
print((age > 18) and (gender == 'F'))
print((age > 25) and (gender == 'F'))
print((age > 18) and (gender != 'F'))
print((age > 25) & (gender != 'F'))

# %%
## >>> Operator "or" <<< ##
print((age > 18) or (gender == 'F'))
print((age > 25) or (gender == 'F'))
print((age > 18) | (gender != 'F'))
print((age > 25) | (gender != 'F'))

# %%
### ---> Determining Leap Year <--- ###
# Receive an input
iYear = int(input("Enter a year: "))
'''
if iYear % 4 == 0:
    if iYear % 100 != 0:
        print(iYear, "is a leap year")
    elif iYear % 400 == 0:
        print(iYear, "is a leap year")
    else:
        print(iYear, "is a not a leap year")
else:
        print(iYear, "is a not a leap year")
'''

# Check if the year is a leap year
isLeapYear =  (iYear % 4 == 0 and iYear % 100 != 0) or (iYear % 400 == 0)

# Display the result
if isLeapYear:
    print(iYear, "is a leap year")
else:
    print(iYear, "is a not a leap year")

# %%
## Conditional Operator
if x > 0:
    y = 1
else:
    y = -1

## is equivalent to
y = 1 if x > 0 else -1

# %% [markdown]
# #<Font color = "Yellow"> Operator Precedence Chart
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# If operators with the same precedence are next to each other, their associativity determines
# the order of evaluation. All binary operators are **left-associative**.
#
#
# For example, since + and –
# are of the same precedence and are left-associative, the expression
#
# a - b + c – d
#
# is equivalent to
#
# ((a - b) + c) - d
