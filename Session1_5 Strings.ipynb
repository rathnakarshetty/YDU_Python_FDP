# %% [markdown]
# <a href="https://colab.research.google.com/github/thegeeksam/PythonProgrammingFDP_June2023/blob/main/Day_4_1_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = "Lime"> **Python Strings** </font>
#
# Python string is a sequence of characters enclosed in either <font color = "Aqua"> **single quotes ('') or double quotes ("")**</font>. Strings are a fundamental data type in Python and are used to represent and manipulate textual data.
#
# Each character is encoded in the ASCII or Unicode character. So we can say that Python strings are also called the collection of Unicode characters.

# %%
print("Hello All")
# Out:
# Hello All

# %%
print('Hello All')
# Out:
# Hello All

# %% [markdown]
# 1. <font color = Aqua> **Creating Strings:** </font> You can create a string by assigning a sequence of characters to a variable.

# %%
my_string = "Hello, world!"

# %% [markdown]
# 2. <font color = Aqua> **Accessing characters:** </font> You can access individual characters in a string using indexing. Python uses zero-based indexing, so the first character is at index 0.

# %%
my_string = "Hello"
print(my_string[0:5:2])  # Output: 'H'

# %% [markdown]
# 3. <font color = Aqua> **String methods:**</font>  Python provides many built-in methods to perform various operations on strings. Some commonly used string methods include <font color = Magenta> ***lower(), upper(), replace(), split(), join(), and len()***.

# %%
my_string = "Hello, World!"
print(my_string)
print("Lower Case: ", my_string.lower())       # Output: "hello, world!"
print("Upper Case: ", my_string.upper())       # Output: "HELLO, WORLD!"
print("Replace \"o\" by \"e\": ", my_string.replace("o", "e"))  # Output: "Helle, Werld!"
print(my_string)
# Out:
# Hello, World!
# Lower Case:  hello, world!
# Upper Case:  HELLO, WORLD!
# Replace "o" by "e":  Helle, Werld!
# Hello, World!

# %%
#The split() method splits a string into a list of substrings
# based on a specified delimiter
sentence = "Hello, how are you today?"
words = sentence.split()  # Splitting by whitespace (default behavior)
print(words) # Output: ['Hello,', 'how', 'are', 'you', 'today?']
print(type(words))
# Out:
# ['Hello,', 'how', 'are', 'you', 'today?']
# <class 'list'>

# %%
#The join() method concatenates a list of strings into a single string,
#using a specified separator.
words = ['Hello,', 'how', 'are', 'you', 'today?']
sentence = ' '.join(words)  # Joining with a space separator
print(sentence) # Output: "Hello, how are you today?"
# Out:
# Hello, how are you today?

# %%
#The len() function returns the length of a string,
#which is the number of characters in the string.
message = "Hello, world!"
length = len(message)
print(length) # Output: 13
# Out:
# 14

# %% [markdown]
# 4.  <font color = Aqua> **String concatenation:**</font>  You can concatenate (combine) strings using the + operator. It allows you to join two or more strings together.

# %%
str1 = "Hello"
str2 = "world!"
result = str1 + " " + str2
print(result)  # Output: "Hello world!"
# Out:
# Hello world!

# %% [markdown]
# 5.  <font color = Aqua> **String formatting:**</font> Python provides several ways to format strings, including the % operator, the format() method, and f-strings (formatted string literals).

# %%
name = "Ramu"
age = 25
print(f"My name is {name} and I'm {age} years old.")
# Output: "My name is Ramu and I'm 25 years old."
# Out:
# My name is Ramu and I'm 25 years old.

# %% [markdown]
# 5.  <font color = Aqua> **String Slicing:**</font> You can extract a portion of a string using slicing. Slicing allows you to specify a start and end index to extract a substring.

# %%
my_string = "Hello, World!"
print(my_string)
print(my_string[0:5])  # Output: "Hello"
my_string = "Hello! Hi!"
print(my_string[0:9:2]) # Output: Hlo i
# Out:
# Hello, World!
# Hello
# Hlo i

# %%
a = input()
for i in range(len(a)):
    if a[i].isupper():
        print(a[i].lower())#,endl="")
    else:
        print(a[i].upper())#,endl="")

# %% [markdown]
# # <font color = "Lime"> **Multiline Strings:**
#
# You can assign a multiline string to a variable by using three quotes:

# %%
a = """A multiline string in Python begins and ends with
either three single quotes or three double quotes.
Any quotes, tabs, or newlines in between the “triple quotes”
are considered part of the string. Python's indentation rules
for blocks do not apply to lines inside a multiline string."""
print(a)

# %% [markdown]
# # <font color = "Lime"> **Strings are Arrays**
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.
#
# ![strings-indexing-and-splitting.png](data:image/png;base64,...)

# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %%
print(a[12])
# Out:
# !

# %%
str = "HELLO"
print(str[0])
print(str[1])
print(str[2])
print(str[3])
print(str[4])
# It returns the IndexError because 6th index doesn't exist
print(str[5])
# Out:
# H
# E
# L
# L
# O
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-cd69d1239810> in <cell line: 8>()
#       6 print(str[4])
#       7 # It returns the IndexError because 6th index doesn't exist
# ----> 8 print(str[5])
#
# IndexError: string index out of range

# %%
a = "hello "
b = "pycoders"
c = 10
print(a + b)
print(a + ' ' + b)
print(a * c)
print(c * b)
# Out:
# hello pycoders
# hello  pycoders
# hello hello hello hello hello hello hello hello hello hello
# pycoderspycoderspycoderspycoderspycoderspycoderspycoderspycoderspycoderspycoders

# %%
my_String = "hello "
print(my_String[2:])
print(my_String[:3])
# Out:
# llo
# hel

# %%
num1="0123456789"
num1[0:7:3]

# %% [markdown]
# ![strings-indexing-and-splitting2.png](data:image/png;base64,...)

# %%
# Given String
str = "welcomepython"
# Start Oth index to end
print(str[0:])
# Starts 1th index to 4th index
print(str[1:5])
# Starts 2nd index to 3rd index
print(str[2:4])
# Starts 0th to 2nd index
print(str[:3])
#Starts 4th to 6th index
print(str[4:7])

# %% [markdown]
# ![strings-indexing-and-splitting3.png](data:image/png;base64,...)

# %%
py='hello'
py[2:4]

# %%
str = 'ONEPLUS'
print(str[-1])
print(str[-3])
print(str[-2:])
print(str[-4:-1])
print(str[-7:-2])
# Reversing the given string
print(str[::-1])
#print(str[-12])
# Out:
# S
# L
# US
# PLU
# ONEPL
# SULPENO

# %%
py="coders"
print(py[::1])
print(py[::-1])
# Out:
# coders
# sredoc

# %%
test_string = 'Python Programming'

string_reversed = test_string[-1::-1]
print(string_reversed)

string_reversed = test_string[::-1]
print(string_reversed)

# %% [markdown]
# # <font color = "Lime"> **Looping Through a String**
# Since strings are arrays, we can loop through the characters in a string, with a for loop.

# %%
for x in "banana":
  print(x)

# %%
a ="Hello"
for i in range(a[4]):
    print(i)

# %% [markdown]
# **Check String**
# To check if a certain phrase or character is present in a string, we can use the keyword **in.**

# %%
txt = "The best things in life are free!"
print("free" in txt)

# %% [markdown]
# # <font color = "Lime"> **Reassigning Strings**
# Updating the content of the strings is as easy as assigning it to a new string. The string object doesn't support item assignment i.e., A string can only be replaced with new string since its content cannot be partially replaced. Strings are immutable in Python.

# %%
str = "HELLO"
#str[0] = "h"
print(str.lower()) #not changing original vbalue.
print(str)
# Out:
# hello
# HELLO

# %%
str = "HELLO"
print(str)
print(str.lower())
str = "hello"
print(str)
# Out:
# HELLO
# hello
# hello

# %% [markdown]
# # <font color = "Lime"> **Slicing**
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
b = "Hello, World!"
print(b[2:5])

# %%
b = "Hello, World!"
print(b[:5])

# %%
b = "Hello, World!"
print(b[2:])

# %% [markdown]
# #<font color = "Lime"> **String format()**
# The format() method allows you to format selected parts of a string.
#
# Sometimes there are parts of a text that you do not control, maybe they come from a database, or user input?
#
# To control such values, add placeholders (curly brackets {}) in the text, and run the values through the format() method:

# %%
#Use the format() method to insert numbers into strings:
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))

# %%
txt = "For only {price:.2f} dollars!"
print(txt.format(price=50.0986))

# %%
#To demonstrate, we insert the number 8 to set the available space for the value to 8 characters.

#Use "<" to left-align the value:

txt = "We have {:<40} chickens."
print(txt.format(49))
# Out:
# We have 49                                       chickens.

# %%
txt1 = "My name is {fname}, I'm {age}".format(fname = "John", age = 36)
txt2 = "My name is {0}, I'm {1}".format("John",36)
txt3 = "My name is {}, I'm {}".format("John",36)

# %% [markdown]
# The format() method takes unlimited number of arguments, and are placed into the respective placeholders:

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity, itemno, price))

# %% [markdown]
# You can use index numbers {0} to be sure the arguments are placed in the correct placeholders:

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want to pay {2} dollars for {0} pieces of item {1}."
print(myorder.format(quantity, itemno, price))

# %%
myorder = "I have a {carname}, it is a {model}."
print(myorder.format(carname = "Ford", model = "Mustang"))
